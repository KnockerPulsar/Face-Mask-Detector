# %%
import torch as t
from torch.utils.data import Dataset, DataLoader

import torchvision as tv
from torchvision import  utils, datasets
from torchvision.transforms import *

import imutils
from imutils.video import VideoStream

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import copy
import time
import os

import cv2
from torch.nn import *
from pathlib import Path
from dataset import MaskDataset
from tqdm import tqdm

# %%
EPOCHS = 10
INIT_LR = 1e-5
BATCH_SIZE = 128
IMG_SIZE = 100
device = t.device("cuda:0" if t.cuda.is_available() else "cpu")
t.manual_seed(42)

# %%
def train_model(model,dataloaders, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for data in tqdm(dataloaders[phase], desc=f"{phase} progress: \t"):
                inputs = data['image'].to(device)
                labels = data['mask'].to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with t.set_grad_enabled(phase == 'train'):
                    outputs = model.forward(inputs)
                    conf, preds = t.max(outputs, 1)
                    
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += t.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, best_acc

# %%
# https://discuss.pytorch.org/t/how-to-add-noise-to-mnist-dataset-when-using-pytorch/59745
class View(Module):
    def __init__(self):
        super().__init__()
        self.std = 0
        self.mean = 0
        return

    def forward(self, tensor):
        return tensor.view(-1, 2048)

    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

# %%
# https://discuss.pytorch.org/t/how-to-add-noise-to-mnist-dataset-when-using-pytorch/59745
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + t.randn(tensor.size()) * self.std + self.mean
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

# %%
from MaskDetector import MaskDetector
val_trns = Compose([
    ToPILImage(),
    Resize((IMG_SIZE, IMG_SIZE)),
    ToTensor()
])

train_trns = Compose([
    ToPILImage(),
    RandomAffine(45, translate=(0.2, 0.2)),
    RandomHorizontalFlip(0.5),
    RandomResizedCrop(int(0.85*IMG_SIZE)),
    Resize((IMG_SIZE, IMG_SIZE)),

    ToTensor(),
    AddGaussianNoise(0., .2)
])

eval_trns = Compose([
    Resize((600, 600)),

    # RandomAffine(45, translate=(0.2, 0.2)),
    # RandomHorizontalFlip(0.5),
    # RandomResizedCrop(int(0.85*IMG_SIZE)),

    ToTensor(),
    # AddGaussianNoise(0., .2)
])


model = MaskDetector(
    Path("./data/mask_df.csv"),
    batch_size=BATCH_SIZE,
    lr=1e-3,
    train_trns=train_trns,
    val_trns=val_trns,
    img_size=(3,IMG_SIZE,IMG_SIZE)
)

model.prepare_data()

train_dl = model.train_dataloader()
val_dl = model.val_dataloader()


dls = {
    "train": train_dl,
    "val": val_dl
}

# print(model)
# Out:
# /home/tarek/.local/lib/python3.6/site-packages/deprecate/deprecation.py:115: LightningDeprecationWarning: The `Accuracy` was deprecated since v1.3.0 in favor of `torchmetrics.classification.accuracy.Accuracy`. It will be removed in v1.5.0.
#   stream(template_mgs % msg_args)
# /home/tarek/.local/lib/python3.6/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
print(device)
# opt = model.configure_optimizers()

# if t.cuda.is_available():
#     model.cuda()

# model, best_acc = train_model(model, dls, model.crossEntropyLoss, opt, t.optim.lr_scheduler.StepLR(opt, 2),EPOCHS)
# mc = open(f"./checkpoints/SZ{IMG_SIZE}_EP{EPOCHS}_LR{INIT_LR}_BS{BATCH_SIZE}_BA{best_acc*100:.2f}%.ckpt", "wb")
# t.save(model.state_dict(), mc)
# mc = open("./face_mask.ckpt", "wb")
# t.save(model.state_dict(), mc)
# else:
model = MaskDetector(unlazy=True, batch_size=1,img_size=100)
checkpoint = t.load("./checkpoints/face_mask.ckpt", map_location=device)
model.load_state_dict(checkpoint['state_dict'],strict=False )
model.to(device)
#     model.load_state_dict(t.load("face_mask.ckpt", map_location=device),
#                         strict=False)
# Out:
# cuda:0
# MaskDetector(
#   (trainAcc): Accuracy()
#   (valAcc): Accuracy()
#   (convLayer1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (convLayer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (convLayer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (linearLayers): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=2, bias=True)
#   )
# )

# %%
# from facenet_pytorch import MTCNN
# mtcnn = MTCNN(image_size=IMG_SIZE, keep_all=True)

from FaceDetector import FaceDetector
mtcnn = FaceDetector(prototype='./checkpoints/deploy.prototxt.txt',
        model='./checkpoints/res10_300x300_ssd_iter_140000.caffemodel')

# %%
labels = ['Mask', 'No mask']
labelColor = [(10, 255, 0), (10, 0, 255)]
font = cv2.FONT_HERSHEY_SIMPLEX


def detect_frame(frame, face_detection_model, face_classifier_model, device):
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    faces = face_detection_model.detect(frame)

    for face in faces:
        x_start, y_start, x_end, y_end = face

        x_start, y_start = max(x_start, 0), max(y_start, 0)

        faceImg = frame[y_start:y_end, x_start:x_end]

        output = face_classifier_model(
            val_trns(faceImg).unsqueeze(0).to(device))
        print(output)
        output = Softmax()(output)
        conf, predicted = t.max(output.data, 1)
        print(predicted)
        verdict = f"{labels[predicted]}: {conf.item()*100:.2f}%"

        cv2.rectangle(frame,
                      (x_start, y_start),
                      (x_end, y_end),
                      labelColor[predicted],
                      thickness=2)

        # draw prediction label
        cv2.putText(frame,
                    verdict,
                    (x_start, y_start-20),
                    font, 0.5, labelColor[predicted], 1) 

    frame = imutils.resize(frame, width=frame_shape[0]*2)
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    return frame

# %%
vs = VideoStream(src=0).start()
cv2.destroyAllWindows()

try:
  while True:


    frame = vs.read()
    frame_shape = frame.shape
    frame = imutils.resize(frame, width=300)
    frame = detect_frame(frame,mtcnn,model,device)

    cv2.imshow("frame", frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
      break
      
    # time.sleep(1)
finally:
  print("Exiting")
  cv2.destroyAllWindows()
  vs.stop()
# Out:
# tensor([[-0.4656,  0.0906]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6042,  0.2118]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6042,  0.2118]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5679,  0.1678]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5679,  0.1678]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5679,  0.1678]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6214,  0.2217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6214,  0.2217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6214,  0.2217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# /home/tarek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# tensor([[-0.5675,  0.1683]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5675,  0.1683]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5675,  0.1683]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3741,  0.0075]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3741,  0.0075]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3741,  0.0075]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5688,  0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5688,  0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5688,  0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4738,  0.0676]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4738,  0.0676]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4738,  0.0676]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5772,  0.1694]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5772,  0.1694]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5772,  0.1694]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6135,  0.2064]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6135,  0.2064]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5801,  0.1954]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5801,  0.1954]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4909,  0.0813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4909,  0.0813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4909,  0.0813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5452,  0.1429]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5452,  0.1429]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5087,  0.1073]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5087,  0.1073]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5087,  0.1073]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6054,  0.1864]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6054,  0.1864]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4897,  0.0951]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4897,  0.0951]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4897,  0.0951]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4735,  0.0734]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.4735,  0.0734]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5064,  0.0995]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5064,  0.0995]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5064,  0.0995]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7253,  0.3480]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7253,  0.3480]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8710,  0.4933]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8710,  0.4933]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8710,  0.4933]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8763,  0.5457]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8763,  0.5457]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8763,  0.5457]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6622,  0.3070]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6622,  0.3070]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5416,  0.2466]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5416,  0.2466]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5416,  0.2466]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2880, -0.0319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2880, -0.0319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2880, -0.0319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8013,  0.4811]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8013,  0.4811]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8013,  0.4811]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5717,  0.2216]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5717,  0.2216]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5717,  0.2216]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6583,  0.3030]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6583,  0.3030]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6583,  0.3030]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7585,  0.4117]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7585,  0.4117]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7585,  0.4117]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2890, -0.0284]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2890, -0.0284]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2890, -0.0284]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1088, -0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1088, -0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1088, -0.1635]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1464, -0.1307]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1464, -0.1307]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1464, -0.1307]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1744, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1744, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1744, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1101, -0.1528]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1101, -0.1528]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1101, -0.1528]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1410, -0.1474]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1410, -0.1474]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1410, -0.1474]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2077, -0.0838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2077, -0.0838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2077, -0.0838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5687,  0.2631]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5687,  0.2631]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5687,  0.2631]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1353, -0.1705]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1353, -0.1705]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1353, -0.1705]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1610, -0.1424]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1610, -0.1424]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1610, -0.1424]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1593, -0.1533]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1593, -0.1533]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1593, -0.1533]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2802, -0.0484]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2802, -0.0484]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2802, -0.0484]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3064, -0.0275]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3064, -0.0275]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3064, -0.0275]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2468, -0.0910]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2468, -0.0910]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2468, -0.0910]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3585, -0.0096]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3585, -0.0096]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3585, -0.0096]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3175, -0.0460]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3175, -0.0460]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3175, -0.0460]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.0884, -0.2643]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0884, -0.2643]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0884, -0.2643]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1653, -0.1906]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1653, -0.1906]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1653, -0.1906]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1052, -0.2534]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1052, -0.2534]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1052, -0.2534]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0503, -0.3077]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0503, -0.3077]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0503, -0.3077]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1381, -0.2233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1381, -0.2233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1381, -0.2233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1016, -0.2517]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1016, -0.2517]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1016, -0.2517]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0245, -0.3251]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0245, -0.3251]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0245, -0.3251]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2187, -0.1374]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2187, -0.1374]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2187, -0.1374]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.0963, -0.2566]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0963, -0.2566]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0963, -0.2566]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2518, -0.1090]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2518, -0.1090]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2518, -0.1090]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1110]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1110]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1110]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2039, -0.1553]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2039, -0.1553]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2039, -0.1553]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2837, -0.0582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2837, -0.0582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2837, -0.0582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1974, -0.1253]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1974, -0.1253]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1974, -0.1253]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1526, -0.1827]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1526, -0.1827]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1526, -0.1827]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2185, -0.1289]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2185, -0.1289]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2185, -0.1289]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3254, -0.0314]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3254, -0.0314]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3254, -0.0314]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3776,  0.0312]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3776,  0.0312]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3776,  0.0312]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3519,  0.0104]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3519,  0.0104]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3519,  0.0104]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1050]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1050]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2378, -0.1050]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3519,  0.0205]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3519,  0.0205]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3088, -0.0175]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3088, -0.0175]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3088, -0.0175]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1833, -0.1505]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1833, -0.1505]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1833, -0.1505]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2132, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2132, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2132, -0.1044]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2173, -0.1043]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2173, -0.1043]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2173, -0.1043]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2085, -0.1176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2085, -0.1176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2085, -0.1176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2412, -0.0804]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2412, -0.0804]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2412, -0.0804]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.0457, -0.2623]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0457, -0.2623]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0457, -0.2623]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0188, -0.2923]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0188, -0.2923]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0188, -0.2923]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1021, -0.2083]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1021, -0.2083]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1021, -0.2083]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1532, -0.1679]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1532, -0.1679]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1532, -0.1679]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2063, -0.1056]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2063, -0.1056]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2063, -0.1056]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1044, -0.2125]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1044, -0.2125]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1044, -0.2125]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0118, -0.2946]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0118, -0.2946]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0118, -0.2946]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1154, -0.1757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1154, -0.1757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1154, -0.1757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2481, -0.0596]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2481, -0.0596]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2481, -0.0596]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1993, -0.1092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1993, -0.1092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1993, -0.1092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1080, -0.2042]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1080, -0.2042]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1080, -0.2042]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0372, -0.3485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0372, -0.3485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0372, -0.3485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0384, -0.3473]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0384, -0.3473]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0384, -0.3473]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0516, -0.2627]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0516, -0.2627]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0516, -0.2627]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0208, -0.3156]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0208, -0.3156]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0208, -0.3156]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0464, -0.3555]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0464, -0.3555]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0464, -0.3555]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2408, -0.5149]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2408, -0.5149]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2408, -0.5149]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1255, -0.4038]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1255, -0.4038]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1255, -0.4038]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1447, -0.4383]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1447, -0.4383]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1447, -0.4383]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4174, -0.7354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4174, -0.7354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4174, -0.7354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1842, -0.4757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1842, -0.4757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1842, -0.4757]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1811, -0.4628]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1811, -0.4628]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1811, -0.4628]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0410, -0.3310]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0410, -0.3310]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0410, -0.3310]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1286, -0.4210]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1286, -0.4210]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.1286, -0.4210]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0915, -0.3885]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0915, -0.3885]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0915, -0.3885]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2166, -0.5153]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2166, -0.5153]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2166, -0.5153]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0172, -0.3003]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0172, -0.3003]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0172, -0.3003]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0667, -0.3721]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0667, -0.3721]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0667, -0.3721]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0542, -0.3600]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0542, -0.3600]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0542, -0.3600]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0269, -0.2788]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0269, -0.2788]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0269, -0.2788]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0510, -0.2436]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0510, -0.2436]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0510, -0.2436]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0793, -0.2345]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0793, -0.2345]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0793, -0.2345]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0315, -0.3440]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0315, -0.3440]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0315, -0.3440]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3154, -1.7431]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3154, -1.7431]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3154, -1.7431]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.8648, -3.2407]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.8648, -3.2407]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.8648, -3.2407]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.5124, -2.8647]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.5124, -2.8647]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.5124, -2.8647]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9006, -2.2343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9006, -2.2343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9006, -2.2343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0462, -2.4346]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0462, -2.4346]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0462, -2.4346]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9981, -2.3805]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9981, -2.3805]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9981, -2.3805]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8783, -2.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8783, -2.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8783, -2.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0055, -2.3653]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0055, -2.3653]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0055, -2.3653]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0695, -2.4011]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0695, -2.4011]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0695, -2.4011]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0340, -2.3594]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0340, -2.3594]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0340, -2.3594]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0054, -2.3500]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0054, -2.3500]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0054, -2.3500]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8869, -2.2430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8869, -2.2430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8869, -2.2430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.2176, -2.5465]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.2176, -2.5465]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.2176, -2.5465]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0484, -2.3835]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0484, -2.3835]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0484, -2.3835]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9883, -2.3339]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9883, -2.3339]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9883, -2.3339]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8772, -2.2173]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8772, -2.2173]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.8772, -2.2173]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9645, -2.3092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9645, -2.3092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9645, -2.3092]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0315, -2.3799]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0315, -2.3799]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0315, -2.3799]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0525, -2.3996]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0525, -2.3996]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0525, -2.3996]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0163, -2.3879]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0163, -2.3879]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0163, -2.3879]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9137, -2.2710]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9137, -2.2710]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9137, -2.2710]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0892, -2.4354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0892, -2.4354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 2.0892, -2.4354]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9950, -2.3720]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9950, -2.3720]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.9950, -2.3720]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3073, -1.6820]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3073, -1.6820]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.3073, -1.6820]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2853, -0.0256]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2853, -0.0256]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2853, -0.0256]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1691, -0.1467]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1691, -0.1467]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1691, -0.1467]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.0685, -0.2411]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0685, -0.2411]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0685, -0.2411]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1407, -0.1485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1407, -0.1485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1407, -0.1485]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2690, -0.0348]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2690, -0.0348]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2690, -0.0348]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3204,  0.0119]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3204,  0.0119]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.3204,  0.0119]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1411, -0.1747]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1411, -0.1747]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1411, -0.1747]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0622, -0.2510]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0622, -0.2510]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0622, -0.2510]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0316, -0.2832]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0316, -0.2832]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0316, -0.2832]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0317, -0.2814]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0317, -0.2814]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0317, -0.2814]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0862, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0862, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0862, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0475, -0.2873]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0475, -0.2873]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0475, -0.2873]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1368, -0.2058]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1368, -0.2058]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1368, -0.2058]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1292, -0.2138]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1292, -0.2138]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1292, -0.2138]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1645, -0.1692]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1645, -0.1692]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1645, -0.1692]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.2367, -0.0985]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2367, -0.0985]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2367, -0.0985]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2339, -0.1094]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2339, -0.1094]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.2339, -0.1094]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1415, -0.1968]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1415, -0.1968]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1415, -0.1968]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1031, -0.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1031, -0.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1031, -0.2293]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1325, -0.2005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1325, -0.2005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1325, -0.2005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0398, -0.2773]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0398, -0.2773]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0398, -0.2773]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1217, -0.2036]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1217, -0.2036]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1217, -0.2036]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1366, -0.1897]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1366, -0.1897]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1366, -0.1897]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0470, -0.2871]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0470, -0.2871]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0470, -0.2871]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0301, -0.3497]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0301, -0.3497]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0301, -0.3497]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1363, -0.1937]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1363, -0.1937]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1363, -0.1937]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1269, -0.1997]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1269, -0.1997]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1269, -0.1997]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1175, -0.2085]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1175, -0.2085]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1175, -0.2085]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0630, -0.2569]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0630, -0.2569]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0630, -0.2569]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1951, -0.1392]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1951, -0.1392]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.1951, -0.1392]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.0868, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0868, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.0868, -0.2402]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1072, -0.2097]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1072, -0.2097]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1072, -0.2097]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1185, -0.2061]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1185, -0.2061]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1185, -0.2061]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1200, -0.2105]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1200, -0.2105]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1200, -0.2105]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1522, -0.1584]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1522, -0.1584]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1522, -0.1584]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# ...
# tensor([0], device='cuda:0')
# tensor([[ 1.6042, -1.9242]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.6042, -1.9242]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2283, -1.5343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2283, -1.5343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2283, -1.5343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0920, -1.3980]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0920, -1.3980]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0920, -1.3980]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1385, -1.4542]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1385, -1.4542]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1385, -1.4542]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2677, -1.5808]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2677, -1.5808]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2677, -1.5808]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4918, -1.8217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4918, -1.8217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4918, -1.8217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1870, -1.5189]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1870, -1.5189]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1870, -1.5189]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2418, -0.5784]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2418, -0.5784]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2418, -0.5784]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.6236,  0.3019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6236,  0.3019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6236,  0.3019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7034,  0.4220]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7034,  0.4220]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7034,  0.4220]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7727,  0.4875]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7727,  0.4875]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7727,  0.4875]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6601,  0.3625]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6601,  0.3625]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6601,  0.3625]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[ 0.0639, -0.4108]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0639, -0.4108]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.0639, -0.4108]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4834, -1.8470]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4834, -1.8470]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.4834, -1.8470]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2783, -1.6545]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2783, -1.6545]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2783, -1.6545]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2992, -1.6842]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2992, -1.6842]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2992, -1.6842]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1503, -1.5319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1503, -1.5319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1503, -1.5319]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1525, -1.5131]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1525, -1.5131]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.1525, -1.5131]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.9785, -1.3435]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.9785, -1.3435]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.9785, -1.3435]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2115, -1.5303]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2115, -1.5303]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2115, -1.5303]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.6032, -1.9777]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.6032, -1.9777]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.6032, -1.9777]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2303, -1.6481]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2303, -1.6481]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2303, -1.6481]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2062, -1.5655]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2062, -1.5655]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.2062, -1.5655]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0832, -1.4233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0832, -1.4233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 1.0832, -1.4233]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4172, -0.7180]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4172, -0.7180]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.4172, -0.7180]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2787, -0.6014]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2787, -0.6014]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2787, -0.6014]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.8886, -1.2575]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.8886, -1.2575]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.8886, -1.2575]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2653, -0.5965]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2653, -0.5965]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[ 0.2653, -0.5965]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1092, -0.1854]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.1092, -0.1854]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([0], device='cuda:0')
# tensor([[-0.5290,  0.1813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5290,  0.1813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.5290,  0.1813]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8435,  0.5385]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8435,  0.5385]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8435,  0.5385]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9204,  0.6400]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9204,  0.6400]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9204,  0.6400]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8349,  0.5552]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8349,  0.5552]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8349,  0.5552]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9014,  0.6298]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9014,  0.6298]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9014,  0.6298]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9224,  0.6430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9224,  0.6430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9224,  0.6430]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9271,  0.6322]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9271,  0.6322]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9271,  0.6322]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0409,  0.7496]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0409,  0.7496]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0409,  0.7496]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9954,  0.7081]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9954,  0.7081]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9954,  0.7081]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0435,  0.7508]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0435,  0.7508]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.0435,  0.7508]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9355,  0.6531]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9355,  0.6531]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9355,  0.6531]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1470,  0.8487]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1470,  0.8487]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1470,  0.8487]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.2053,  0.9033]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.2053,  0.9033]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.2053,  0.9033]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1134,  0.8295]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1134,  0.8295]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1134,  0.8295]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9244,  0.6582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9244,  0.6582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9244,  0.6582]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8566,  0.6019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8566,  0.6019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8566,  0.6019]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8417,  0.5838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8417,  0.5838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.8417,  0.5838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7991,  0.5433]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7991,  0.5433]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7991,  0.5433]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9467,  0.6966]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9467,  0.6966]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9467,  0.6966]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1114,  0.8532]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1114,  0.8532]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-1.1114,  0.8532]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9814,  0.7176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9814,  0.7176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.9814,  0.7176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7574,  0.4893]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7574,  0.4893]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.7574,  0.4893]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6561,  0.4197]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6561,  0.4197]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6561,  0.4197]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6337,  0.4005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6337,  0.4005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6337,  0.4005]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6463,  0.3895]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# tensor([[-0.6463,  0.3895]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([1], device='cuda:0')
# Exiting
